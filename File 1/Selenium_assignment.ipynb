# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# %%
# Answer 4

# %%
# Initialize the WebDriver
driver = webdriver.Chrome()

# %%
# Navigate to the website
driver.get('https://www.flipkart.com/')

# %%
# Search for Sunglasses
sunglass=driver.find_element(By.CLASS_NAME,'Pke_EE')
sunglass.send_keys('Sunglasses')

# %%
# Click on the Search button
search=driver.find_element(By.CLASS_NAME,'_2iLD__')
search.click()

# %%
brand=[]
protection=[]
description=[]
price=[]

# %%
# Brand Name
brand_name=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_name[0:100]:
    brand_=i.text
    brand.append(brand_name)
# Protection
protect=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in protect:
    protection_=i.text
    protection.append(protect)
#Price
rate=driver.find_elements(By.XPATH,'//div[@class="_3I9_wc"]')
for i in rate:
    rate_=i.text
    price.append(rate)
# Discount
discount=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in discount:
    discount_=i.text
    description.append(discount)

# %%
print(len(brand), len(protection), len(description), len(price))
# Out:
# 487 378 358 398

# %%
df=pd.DataFrame([brand, protection, description, price])
df.T
# Out:
#                                                      0  \
# 0    [<selenium.webdriver.remote.webelement.WebElem...
# 1    [<selenium.webdriver.remote.webelement.WebElem...
# 2    [<selenium.webdriver.remote.webelement.WebElem...
# 3    [<selenium.webdriver.remote.webelement.WebElem...
# 4    [<selenium.webdriver.remote.webelement.WebElem...
# ..                                                 ...
# 442  [<selenium.webdriver.remote.webelement.WebElem...
# 443  [<selenium.webdriver.remote.webelement.WebElem...
# 444  [<selenium.webdriver.remote.webelement.WebElem...
# 445  [<selenium.webdriver.remote.webelement.WebElem...
# 446  [<selenium.webdriver.remote.webelement.WebElem...
#
#                                                      1  \
# 0    <selenium.webdriver.remote.webelement.WebEleme...
# 1    <selenium.webdriver.remote.webelement.WebEleme...
# 2    <selenium.webdriver.remote.webelement.WebEleme...
# 3    <selenium.webdriver.remote.webelement.WebEleme...
# ...

# %%
#Answer 6

# %%
driver=webdriver.Chrome()
driver.get('https://www.flipkart.com/')

# %%
# Search for sneakers
sneaker=driver.find_element(By.CLASS_NAME,'Pke_EE')
sneaker.send_keys('Top 100 Sneakers')

# %%
#Click on search
search=driver.find_element(By.CLASS_NAME,'_2iLD__')
search.click()

# %%
brand=[]
price=[]
description=[]

# %%
# Brand Name
brand_name=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_name:
    brand_=i.text
    brand.append(brand_name)
#Price
rate=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in rate:
    rate_=i.text
    price.append(rate)
# Discount
discount=driver.find_elements(By.XPATH,'//div[@class="_1xHGtK _373qXS"]')
for i in discount:
    discount_=i.text
    description.append(discount)

# %%
df=pd.DataFrame({'Brand':brand, 'Price': price, 'Description': description})
df
# Out:
#                                                 Brand  \
# 0   [<selenium.webdriver.remote.webelement.WebElem...
# 1   [<selenium.webdriver.remote.webelement.WebElem...
# 2   [<selenium.webdriver.remote.webelement.WebElem...
# 3   [<selenium.webdriver.remote.webelement.WebElem...
# 4   [<selenium.webdriver.remote.webelement.WebElem...
# 5   [<selenium.webdriver.remote.webelement.WebElem...
# 6   [<selenium.webdriver.remote.webelement.WebElem...
# 7   [<selenium.webdriver.remote.webelement.WebElem...
# 8   [<selenium.webdriver.remote.webelement.WebElem...
# 9   [<selenium.webdriver.remote.webelement.WebElem...
# 10  [<selenium.webdriver.remote.webelement.WebElem...
# 11  [<selenium.webdriver.remote.webelement.WebElem...
# 12  [<selenium.webdriver.remote.webelement.WebElem...
# 13  [<selenium.webdriver.remote.webelement.WebElem...
# 14  [<selenium.webdriver.remote.webelement.WebElem...
# 15  [<selenium.webdriver.remote.webelement.WebElem...
# ...

# %%
#Answer 7

# %%
driver=webdriver.Chrome()
driver.get('https://www.amazon.com/')

# %%
# Search for laptop
sneaker=driver.find_element(By.CLASS_NAME,'nav-input nav-progressive-attribute')
sneaker.send_keys('Laptop')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2152/1961626464.py in <module>
#       1 # Search for laptop
# ----> 2 sneaker=driver.find_element(By.CLASS_NAME,'nav-input nav-progressive-attribute')
#       3 sneaker.send_keys('Laptop')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# ...

# %%
#Answer 8

# %%
driver=webdriver.Chrome()
driver.get('https://www.azquotes.com/')

# %%
# Search for quotes
sneaker=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
sneaker.send_keys('Top Quotes')

# %%
# Search 
sneaker=driver.find_element(By.CLASS_NAME,'collapse')
sneaker.click()

# %%
Quotes=[]
Author=[]
Type=[]

# %%
# Quote
quote_name=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quote_name:
    name=i.text
    Quotes.append(quote_name)
#Author
author_name=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author_name:
    name_1=i.text
    Author.append(author_name)
# Type of Quote
quote_type=driver.find_elements(By.XPATH,'//div[@class="tags"]')
for i in quote_type:
    type=i.text
    Type.append(quote_type)

# %%
print(len(Quotes), len(Author), len(Type))
# Out:
# 104 200 200

# %%
df=pd.DataFrame([Quotes, Author, Type])
df.T
# Out:
#                                                      0  \
# 0    [<selenium.webdriver.remote.webelement.WebElem...
# 1    [<selenium.webdriver.remote.webelement.WebElem...
# 2    [<selenium.webdriver.remote.webelement.WebElem...
# 3    [<selenium.webdriver.remote.webelement.WebElem...
# 4    [<selenium.webdriver.remote.webelement.WebElem...
# ..                                                 ...
# 195                                               None
# 196                                               None
# 197                                               None
# 198                                               None
# 199                                               None
#
#                                                      1  \
# 0    [<selenium.webdriver.remote.webelement.WebElem...
# 1    [<selenium.webdriver.remote.webelement.WebElem...
# 2    [<selenium.webdriver.remote.webelement.WebElem...
# 3    [<selenium.webdriver.remote.webelement.WebElem...
# ...

# %%
#Answer 9

# %%
driver=webdriver.Chrome()
driver.get('https://www.jagranjosh.com/')

# %%
# Search forGK
sneaker=driver.find_element(By.XPATH,'/html/body/div/header/nav/div/div/div[3]/ul/li[3]/a')
sneaker.send_keys('GK')

# %%
# Search 
sneaker=driver.find_element(By.XPATH,'/html/body/div/header/nav/div/div/div[4]/i/svg')
sneaker.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2152/960199713.py in <module>
#       1 # Search
# ----> 2 sneaker=driver.find_element(By.XPATH,'/html/body/div/header/nav/div/div/div[4]/i/svg')
#       3 sneaker.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     736             value = f'[name="{value}"]'
#     737
# --> 738         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     739
#     740     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     342         response = self.command_executor.execute(driver_command, params)
#     343         if response:
# ...
